# %%
# %load_ext autoreload

# %% [markdown]
# ```python
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from PIL import ImageChops, ImageFilter
# from PIL import Image, ImageDraw, ImageFont, ImageOps
# ```

# %% [markdown]
# ```python
# %autoreload 2
# from mabot.agents.surfer_rag import get_graph, WebSurferState, Logger
# from mabot.browser.base import WebElementSelectorMain
# from mabot.browser.browser import Browser
# from mabot.browser.utils.web_element import WebElementRectangleCollection
# ```

# %% [markdown]
# ```python
# selector = WebElementSelectorMain(xpath="//*", is_displayed=True, cursor=None)
# browser = Browser(
#     "https://www.google.com/",
#     selector=selector,
#     headless=False,
# )
# ```

# %% [markdown]
# ```python
# graph = get_graph()
# ```

# %% [markdown]
# ```python
# state = WebSurferState(
#     browser=browser,
#     prediction=None,
#     user_prompt="Create a new google account with the name Batya Botov for personal use.",
#     # observation="Google page.",
#     observation="Start from google main page.",
#     history=[],
#     logger=Logger(),
#     new_elements=WebElementRectangleCollection({}),
# )
# graph.invoke(state, config={"recursion_limit": 100})
# ```

# %% [markdown]
# ```python
# page = browser.get_page()
# ```

# %%
# page.elements

# %% [markdown]
# ```python
# collection = page.prompt_element("Sign in", action="click")
# ```

# %% [markdown]
# ```python
# collection.screenshot_numbered_elements().view
# ```

# %% [markdown]
# ```python
# element = page.get_element_by_id(
#     "f.538436237F69BFC7B39B4AE039F9BFA5.d.DD7B8BA6C0D80D9D8DAA3D439101A892.e.146"
# )
# ```

# %% [markdown]
# ```python
# from selenium import webdriver
#
# webdriver.ActionChains(browser.driver).move_to_element(element).pause(
#     1
# ).perform()
# element.value_of_css_property("cursor")
# ```

# %% [markdown]
# ```python
# collection.scores
# ```

# %% [markdown]
# ```python
# collection.get_element().id
# ```

# %% [markdown]
# ```python
# img1
# ```

# %% [markdown]
# ```python
# img0
# ```

# %% [markdown]
# ```python
# diff = ImageChops.difference(img1, img0)
# diff
# ```

# %% [markdown]
# ```python
# import cv2
# ```

# %% [markdown]
# ```python
# cv.convexHull(points[, hull[, clockwise[, returnPoints]]])
# ```
