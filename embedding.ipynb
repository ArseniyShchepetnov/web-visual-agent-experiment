# %%
# %load_ext autoreload

# %% [markdown]
# ```python
# import base64
# from io import BytesIO
#
# import ollama
# from PIL import Image
# ```

# %% [markdown]
# ```python
# %autoreload 2
# from mabot.agents.prompts import ElementReRankingPrompt
# from mabot.browser.base import WebElementSelectorMain
# from mabot.browser.browser import Browser
# from mabot.browser.utils.image import base64_to_image
# ```

# %% [markdown]
# ```python
# selector = WebElementSelectorMain(xpath="//*", is_displayed=True)
# browser = Browser(
#     "https://www.google.com/",
#     selector=selector,
#     headless=False,
#     # width=800,
#     # height=600,
# )
# ```

# %% [markdown]
# ```python
# screen = browser.screenshot_base64()
# base64_to_image(screen)
# ```

# %% [markdown]
# ```python
# img = base64_to_image(screen)
# ```

# %% [markdown]
# ```python
# page = browser.get_page()
# ```

# %% [markdown]
# ```python
# collection = page.prompt_element("Create account", k=5, action="click")
# ```

# %% [markdown]
# ```python
# collection.screenshot_numbered_elements().view
# ```

# %% [markdown]
# ```python
# base64_to_image(collection.scores[3][1].screenshot_as_base64)
# ```

# %% [markdown]
# ```python
# collection.scores[5][1].value_of_css_property("cursor")
# ```

# %% [markdown]
# ```python
# collection.scores[0][1].click()
# ```

# %% [markdown]
# ```python
# collection.type_text("Hello new world")
# ```

# %% [markdown]
# ```python
# prompt = (
#     f"{ElementReRankingPrompt().template}\n"
#     "*Thought*: The current page is the Google homepage, and we need to create a new Google account\n"
#     "*action*: Click[Sign in]"
# )
# ```

# %% [markdown]
# ```python
# collection.screenshot_numbered_elements().view.save("img.png")
# mes = ollama.generate(
#     model="llama3.2-vision",
#     prompt=prompt,
#     images=["/Users/arseniy/Documents/Workspace/mabot/img.png"],
# )
# ```

# %% [markdown]
# ```python
# mes
# ```

# %% [markdown]
# ```python
# Image.open(
#     BytesIO(
#         base64.b64decode(browser.rag_view.elements[0].screenshot_as_base64)
#     )
# )
# ```

# %% [markdown]
# ```python
# browser.screenshot_image()
# ```

# %% [markdown]
# ```python
# view.prompt_element_id("photo of armchair", k=25)
# ```

# %% [markdown]
# ```python
# view.get_element_img(90)
# ```

# %% [markdown]
# ```python
# x = view.embedding.get_nearest_examples("photo of rocket", k=25)
# ```

# %% [markdown]
# ```python
# from PIL import Image
# from transformers import CLIPModel, CLIPProcessor
#
# model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
# processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
#
# image = [view.get_element_img(id_) for id_ in view.elements]
#
# inputs = processor(
#     text=["a photo of armchair"],
#     images=image,
#     return_tensors="pt",
#     padding=True,
# )
#
# outputs = model(**inputs)
# logits_per_image = (
#     outputs.logits_per_image
# )  # this is the image-text similarity score
# ```

# %% [markdown]
# ```python
# logits_per_image[:, 0].argsort()
# ```

# %% [markdown]
# ```python
# image[142]
# ```

# %% [markdown]
# ```python
# x[1]["image"][0]
# ```

# %% [markdown]
# ```python
# images = [view.get_element_img(id_) for id_ in range(len(view.elements))]
# ```

# %% [markdown]
# ```python
# import torch
# from PIL import Image
# from transformers import AutoImageProcessor, AutoModel, AutoTokenizer
#
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# model = AutoModel.from_pretrained("openai/clip-vit-base-patch16").to(device)
# processor = AutoImageProcessor.from_pretrained("openai/clip-vit-base-patch16")
# tokenizer = AutoTokenizer.from_pretrained("openai/clip-vit-base-patch16")
# ```

# %% [markdown]
# ```python
# model.get_image_features(**processor(images, return_tensors="pt")).shape
# ```

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 9
#       1 classes = ["photo of log in button"]
#       2 inputs = processor(
#       3     images=images,
#       4     return_tensors="pt",
#       5     padding=True,
#       6     do_convert_rgb=False,
#       7 )
# ----> 9 outputs = model(**inputs)
#      10 logits_per_image = (
#      11     outputs.logits_per_image
#      12 )  # this is the image-text similarity score
#      13 probs = logits_per_image.softmax(
#      14     dim=1
#      15 )  # we can take the softmax to get the label probabilities
#
# File ~/Library/Caches/pypoetry/virtualenvs/mabot-VHhL2YHK-py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# ...

# %% [markdown]
# ```python
# logits_per_image.squeeze().topk(3)
# ```

# %%
import re

# %% [markdown]
# ```python
# x = re.match(
#     r"\*action\*.+",
#     "*thought*: briefly summarize the info that will help to solve the **User Prompt**.\n*action* aedafdafda",
# )
# ```

# %%
x = re.search(
    r"\*thought\*\s*:(.+)\*action\*\s*:?(.+)",
    "*thought*: briefly adfaadf *action*: adqfada",
)
x
# Out:
# <re.Match object; span=(0, 44), match='*thought*: briefly adfaadf *action*: adqfada'>

# %%
x

# %%
x.span(0)
# Out:
# (8, 25)

# %%
x.string
# Out:
# 'adfaadf *action*: adqfada'
